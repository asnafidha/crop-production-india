# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## crop production in india

# %%
cp=pd.read_csv(r'C:\Users\User\Documents\crop_india\crop_production.csv')
cp
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %%
cp.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
cp.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.423610e+05
# mean     2005.643018  1.200282e+04  5.825034e+05
# std         4.952164  5.052340e+04  1.706581e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  8.800000e+01
# 50%      2006.000000  5.820000e+02  7.290000e+02
# 75%      2010.000000  4.392000e+03  7.023000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
cp.shape
# Out:
# (246091, 7)

# %% [markdown]
# ## data cleaning and mining

# %%
cp.isnull().sum()
# Out:
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64

# %%
cp['Production'].fillna(0, inplace=True)

# %%
cp.isnull().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
cp
# Out:
#                          State_Name District_Name  Crop_Year       Season  \
# 0       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2       Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4       Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# ...                             ...           ...        ...          ...
# 246086                  West Bengal       PURULIA       2014  Summer
# 246087                  West Bengal       PURULIA       2014  Summer
# 246088                  West Bengal       PURULIA       2014  Whole Year
# 246089                  West Bengal       PURULIA       2014  Winter
# 246090                  West Bengal       PURULIA       2014  Winter
#
#                        Crop      Area  Production
# 0                  Arecanut    1254.0      2000.0
# 1       Other Kharif pulses       2.0         1.0
# 2                      Rice     102.0       321.0
# 3                    Banana     176.0       641.0
# 4                 Cashewnut     720.0       165.0
# ...                     ...       ...         ...
# 246086                 Rice     306.0       801.0
# 246087              Sesamum     627.0       463.0
# 246088            Sugarcane     324.0     16250.0
# 246089                 Rice  279151.0    597899.0
# 246090              Sesamum     175.0        88.0
#
# [246091 rows x 7 columns]

# %%
duplicates = cp.duplicated()
print("Number of duplicates:", duplicates.sum())
data = cp[~duplicates]
# Out:
# Number of duplicates: 0

# %%
cp.describe()
# Out:
#            Crop_Year          Area    Production
# count  246091.000000  2.460910e+05  2.460910e+05
# mean     2005.643018  1.200282e+04  5.736744e+05
# std         4.952164  5.052340e+04  1.693614e+07
# min      1997.000000  4.000000e-02  0.000000e+00
# 25%      2002.000000  8.000000e+01  7.700000e+01
# 50%      2006.000000  5.820000e+02  6.910000e+02
# 75%      2010.000000  4.392000e+03  6.769000e+03
# max      2015.000000  8.580100e+06  1.250800e+09

# %%
#state-wise count
cp.State_Name.value_counts()
# Out:
# State_Name
# Uttar Pradesh                  33306
# Madhya Pradesh                 22943
# Karnataka                      21122
# Bihar                          18885
# Assam                          14628
# Odisha                         13575
# Tamil Nadu                     13547
# Maharashtra                    12628
# Rajasthan                      12514
# Chhattisgarh                   10709
# Andhra Pradesh                  9628
# West Bengal                     9613
# Gujarat                         8436
# Haryana                         5875
# Telangana                       5649
# Uttarakhand                     4896
# Kerala                          4261
# Nagaland                        3906
# Punjab                          3173
# Meghalaya                       2867
# Arunachal Pradesh               2546
# Himachal Pradesh                2494
# Jammu and Kashmir               1634
# Tripura                         1412
# Manipur                         1267
# Jharkhand                       1266
# Mizoram                          957
# Puducherry                       876
# Sikkim                           714
# Dadra and Nagar Haveli           263
# Goa                              208
# Andaman and Nicobar Islands      203
# Chandigarh                        90
# Name: count, dtype: int64

# %%
#district-wise
cp.District_Name.value_counts()
# Out:
# District_Name
# BIJAPUR      945
# TUMKUR       936
# BELGAUM      925
# HASSAN       895
# BELLARY      887
#             ...
# HYDERABAD      8
# KHUNTI         6
# RAMGARH        6
# NAMSAI         1
# MUMBAI         1
# Name: count, Length: 646, dtype: int64

# %%
#crop year -wise counts
cp.Crop_Year.value_counts()
# Out:
# Crop_Year
# 2003    17287
# 2002    16671
# 2008    14550
# 2007    14526
# 2006    14328
# 2004    14117
# 2009    14116
# 2011    14071
# 2010    14065
# 2005    13799
# 2000    13658
# 2013    13650
# 2012    13410
# 2001    13361
# 1999    12515
# 1998    11533
# 2014    10973
# 1997     8899
# 2015      562
# Name: count, dtype: int64

# %%
#season wise
cp.Season.value_counts()
# Out:
# Season
# Kharif         95951
# Rabi           66987
# Whole Year     57305
# Summer         14841
# Winter          6058
# Autumn          4949
# Name: count, dtype: int64

# %%
#CROP WISE
cp.Crop.value_counts()
# Out:
# Crop
# Rice                 15104
# Maize                13947
# Moong(Green Gram)    10318
# Urad                  9850
# Sesamum               9046
#                      ...
# Litchi                   6
# Coffee                   6
# Apple                    4
# Peach                    4
# Other Dry Fruit          1
# Name: count, Length: 124, dtype: int64

# %% [markdown]
# ## EDA and Visualization

# %% [markdown]
# **CROP PRODUCTION TRENDS OVER THE YEAR**

# %%
plt.figure(figsize=(25, 15))
sns.lineplot(x='Crop_Year', y='Production', data=cp)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x='Crop_Year', y='Production', data=cp)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *Production rate was very low in the year of 1997.but afterward it increased.
#
# *In the year 2011 there was drastic increase in the Crop Production and it continued till 2014.
#
# *in 2015 there was huge downfall in crop production.

# %% [markdown]
# **TOP CROPS BASED ON PRODUCTION**

# %%
top_crops = data.groupby('Crop')['Production'].sum().nlargest(10).reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='Production', y='Crop', data=top_crops)
plt.title('Top 10 Crops in India based on Production')
plt.xlabel('Total Production')
plt.ylabel('Crop')
plt.show()

# %% [markdown]
# * production of coconuts is the the highest value when compared to other crops. we can also see a small value of production of sugarcanes.

# %% [markdown]
# **CROPS PRODUCTION IN PARTICULAR SEASON**

# %%
plt.hist(cp['Season'])
# Out:
# (array([95951.,     0., 57305.,     0.,  4949.,     0., 66987.,     0.,
#         14841.,  6058.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# * in Kharif season are drastically high as compare to others And variety of crops in Summer, Winter and autumn are drastically low.

# %% [markdown]
# **PRODUCTION RATE OF CROP IN EVERY STAES IN INDIA**

# %%
plt.figure(figsize=(25, 15))
sns.barplot(x='State_Name', y='Production', data=cp)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *Kerala's production rate is drastically high as compare to others.
#
# *most of the North Eastern States Produces very less amount of Crops.

# %% [markdown]
# **THE STATE WISE AREA OF AGRICULTURAL LAND**

# %%
plt.figure(figsize=(25, 15))
sns.barplot(x='State_Name', y='Area', data=cp)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *Punjab has the largest area for agriculture and maharashtra has the second largest and west bengal has the third largest area for agriculture. We can also infer that chandigarh has the smallest area for agriculture.

# %% [markdown]
# **AGRICULTURAL AREA IN DIFFRENT YEAR INTERVALS**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Crop_Year', y='Area', data=cp)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# *the agriculture area was the largest during the year 1997 right after that we can see a drastic decline in the agriculture area from the year 2000. We can see further declining of the area from the year 2015.

# %% [markdown]
# **AGRICULTURE AREA IN DIFFRENT SEASON**

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Season', y='Area', data=cp)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# *in the winter season the Agriculture area is the largest with value of 35000. We can also infer that during summer season the agriculture area is very less.

# %% [markdown]
# **AGRICULTURE AREA OF DIFFRENT CROP YEAR**

# %%
plt.figure(figsize=(25, 15))
sns.barplot(x='Crop_Year', y='Area', data=cp)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * 1997 has the largest agriculture area and it has been declining since then. In the visualization the smallest agriculture area is for the crop year 2015.

# %% [markdown]
# **CONCLUSION**
# *year
#
# *Production wise top zone is South zone with Kerala topping it’s high crop production.
#
# *Production wise top crop type are Coconut, Sugarcane and Rice.
#
# *Total Production hit peak in the year 2011 and 2013.and 2015 was worst
#
# *Top crop categories which shows high production values are Whole Year(Annual growing plants),Kharif and Rabi crops. It clearly shows these crops heavily dependent on seasonal monsoons.
#
#
# *Top crop categories are Cereal, Pulses and Oilseeds
#
# *Top producing state Kerala shows a abundance of whole year seasonal crops and
# Top producing state Uttar Pradesh shows abundance of Kharif, Rabi and Summer crops.
